# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import ttest_ind

# %%
df_crime_rate = pd.read_csv('data/Crime_rate_1960-2019.csv')
df_crime_rate = df_crime_rate.drop(['Unnamed: 1','Unnamed: 2'],axis=1)
df_crime_rate
# Out:
#     Year    Population     Total  Violent  Property  Murder  Forcible Rape   \
# 0   1960   179,323,175   1,887.2    160.9   1,726.3     5.1            9.6
# 1   1961   182,992,000   1,906.1    158.1   1,747.9     4.8            9.4
# 2   1962   185,771,000   2,019.8    162.3   1,857.5     4.6            9.4
# 3   1963   188,483,000   2,180.3    168.2   2,012.1     4.6            9.4
# 4   1964   191,141,000   2,388.1    190.6   2,197.5     4.9           11.2
# 5   1965   193,526,000   2,449.0    200.2   2,248.8     5.1           12.1
# 6   1966   195,576,000   2,670.8    220.0   2,450.9     5.6           13.2
# 7   1967   197,457,000   2,989.7    253.2   2,736.5     6.2           14.0
# 8   1968   199,399,000   3,370.2    298.4   3,071.8     6.9           15.9
# 9   1969   201,385,000   3,680.0    328.7   3,351.3     7.3           18.5
# 10  1970   203,235,298   3,984.5    363.5   3,621.0     7.9           18.7
# ...

# %%
df_inflation = pd.read_csv('data/US_inflation_rates.csv')
df_inflation
# Out:
#            date    value
# 0    1947-01-01   21.480
# 1    1947-02-01   21.620
# 2    1947-03-01   22.000
# 3    1947-04-01   22.000
# 4    1947-05-01   21.950
# ..          ...      ...
# 913  2023-02-01  301.648
# 914  2023-03-01  301.808
# 915  2023-04-01  302.918
# 916  2023-05-01  303.294
# 917  2023-06-01  303.841
#
# [918 rows x 2 columns]

# %%
df_population = pd.read_csv('data/united-states-population-2023-11-16.csv')
df_population # i dont know if this data is neccessary or not because we may need to use the change rate of the poulation
# Out:
#            date  Population  Annual % Change
# 0    1950-12-31   148281550              NaN
# 1    1951-12-31   150598453             1.56
# 2    1952-12-31   152941727             1.56
# 3    1953-12-31   155451199             1.64
# 4    1954-12-31   158205873             1.77
# ..          ...         ...              ...
# 146  2096-12-31   393602753             0.03
# 147  2097-12-31   393728779             0.03
# 148  2098-12-31   393843026             0.03
# 149  2099-12-31   393946323             0.03
# 150  2100-12-31   394041155             0.02
#
# [151 rows x 3 columns]
